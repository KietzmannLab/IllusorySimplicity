# %%
import os
from os import path
import numpy as np
from macaquethings.plotting.anatomical import plot_data_on_anatomy
from macaquethings.plotting.default_styles import *
import matplotlib.pyplot as plt

figure_style()  # set consistent plotting defaults for all figs

nans = np.empty(1024)
nans.fill(np.nan)

os.makedirs('anatomy_templates', exist_ok=True)

plot_data_on_anatomy('monkeyF', nans, root='../..')
plt.savefig(path.join('anatomy_templates', 'monkeyF.svg'))

plot_data_on_anatomy('monkeyN', nans, root='../..')
plt.savefig(path.join('anatomy_templates', 'monkeyN.svg'))
